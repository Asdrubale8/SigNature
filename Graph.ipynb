# %% [markdown]
# #Graphs to compare the models

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##Writer dependent models

# %%
x1 = [x/2 for x in [2, 4, 6, 8, 10, 18.82608695652174, 28.391304347826086, 37.95652173913044, 47.56521739130435, 57.04347826086956, 66.6086956521739, 76.17391304347827, 85.73913043478261]]
y1 = [0.820000, 0.826667, 0.826667, 0.833333, 0.853333, 0.873333, 0.900000, 0.906667, 0.906667, 0.906667, 0.926667, 0.933333, 0.946667]
plt.plot(x1,y1, c='b', label="Tailored")

x2 = [x/2 for x in [2, 4, 6, 8, 10, 18.82608695652174, 28.391304347826086, 37.95652173913044, 47.56521739130435, 57.04347826086956, 66.6086956521739, 76.17391304347827, 85.73913043478261]]
y2 = [0.726667, 0.813333, 0.813333, 0.833333, 0.866667, 0.913333, 0.920000, 0.926667, 0.906667, 0.906667, 0.933333, 0.966667, 0.980000]
plt.plot(x2,y2, c='r', label="Fine tuning")

plt.legend(loc="lower right")

plt.xlabel('Number of istances')
plt.ylabel('Accuracy')

plt.show()

# %% [markdown]
# ##Writer independent model

# %%
x1 = list(range(1, 29 + 1, 2))
y1 = [0.7866666666666666, 0.8133333333333334, 0.8333333333333334, 0.88, 0.8466666666666667, 0.84, 0.8666666666666667, 0.86, 0.86, 0.86, 0.8466666666666667, 0.8533333333333334, 0.8533333333333334, 0.8733333333333333, 0.8533333333333334]

plt.plot(x1,y1, 'b')

plt.xlabel('Number of istances')
plt.ylabel('Teorical Accuracy')

plt.show()

# %% [markdown]
# ##Comparison between both approaches

# %%
x1 = [x/2 for x in [2, 4, 6, 8, 10, 18.82608695652174, 28.391304347826086, 37.95652173913044, 47.56521739130435, 57.04347826086956]]
y1 = [0.820000, 0.826667, 0.826667, 0.833333, 0.853333, 0.873333, 0.900000, 0.906667, 0.906667, 0.906667]
plt.plot(x1,y1, c='b', label="Tailored")

x2 = [x/2 for x in [2, 4, 6, 8, 10, 18.82608695652174, 28.391304347826086, 37.95652173913044, 47.56521739130435, 57.04347826086956]]
y2 = [0.726667, 0.813333, 0.813333, 0.833333, 0.866667, 0.913333, 0.920000, 0.926667, 0.906667, 0.906667]#, 0.933333, 0.966667, 0.980000]
plt.plot(x2,y2, c='r', label="Fine tuning")

x3 = list(range(1, 29 + 1, 2))
y3 = [0.7866666666666666, 0.8133333333333334, 0.8333333333333334, 0.88, 0.8466666666666667, 0.84, 0.8666666666666667, 0.86, 0.86, 0.86, 0.8466666666666667, 0.8533333333333334, 0.8533333333333334, 0.8733333333333333, 0.8533333333333334]
plt.plot(x3,y3, c='g', label="Election siamese")

plt.legend(loc="lower right")

plt.xlabel('Number of istances')
plt.ylabel('Accuracy')


plt.show()

# %%
x1 = [x/2 for x in [2, 4, 6, 8, 10, 18.82608695652174]]
y1 = [0.820000, 0.826667, 0.826667, 0.833333, 0.853333, 0.873333]
plt.plot(x1,y1, c='b', label="Tailored")

x2 = [x/2 for x in [2, 4, 6, 8, 10, 18.82608695652174]]
y2 = [0.726667, 0.813333, 0.813333, 0.833333, 0.866667, 0.913333]
plt.plot(x2,y2, c='r', label="Fine tuning")

x3 = list(range(1, 10, 2))
y3 = [0.7866666666666666, 0.8133333333333334, 0.8333333333333334, 0.88, 0.8466666666666667]
plt.plot(x3,y3, c='g', label="Election siamese")

plt.legend(loc="lower right")

plt.xlabel('Number of istances')
plt.ylabel('Accuracy')


plt.show()
